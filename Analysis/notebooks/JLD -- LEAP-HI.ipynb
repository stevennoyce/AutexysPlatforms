# %%
import os
import sys

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../../../AutexysHost/source')
    
from utilities import DataLoggerUtility as dlu
from utilities import DataPlotterUtility as dpu
mplu = dpu.mplu
from utilities import FET_Modeling as fet_model
#from procedures import Device_History as DH

import numpy as np

# %%
data_LHL1_G1D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/1/G1-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL1_G1D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/1/G1-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL1_G2D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/1/G2-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL1_G2D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/1/G2-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL1 = [data_LHL1_G1D1,data_LHL1_G1D2,data_LHL1_G2D1,data_LHL1_G2D2]

data_LHL2_G1D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/2/G1-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL2_G1D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/2/G1-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL2_G2D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/2/G2-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL2_G2D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/2/G2-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL2 = [data_LHL2_G1D1,data_LHL2_G1D2,data_LHL2_G2D1,data_LHL2_G2D2]

data_LHL3_G1D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/3/G1-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL3_G1D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/3/G1-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL3_G2D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/3/G2-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL3_G2D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/3/G2-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL3 = [data_LHL3_G1D1,data_LHL3_G1D2,data_LHL3_G2D1,data_LHL3_G2D2]

data_LHL4_G1D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/4/G1-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL4_G1D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/4/G1-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL4_G2D1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/4/G2-D1', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL4_G2D2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/LEAP-HI/LHL/4/G2-D2', 'GateSweep.json', minExperiment=2, maxExperiment=2)[0]
data_LHL4 = [data_LHL4_G1D1,data_LHL4_G1D2,data_LHL4_G2D1,data_LHL4_G2D2]

fig, (ax,) = dpu.makeDevicePlot('SubthresholdCurve', data_LHL1, data_LHL1[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'publication_mode':False, 'figureSizeOverride':(2,2.5)})
for data in data_LHL1:
    x_lines, y_lines, y_error = mplu.extractSweep(ax, data, 'both', x_data='gate voltage', y_data='gate current')
    for x,y in zip(x_lines, y_lines): 
        line = ax.plot(np.array(x), np.abs(y), color="#4FB99F", marker='o', markersize=2, linewidth=1)[0]
ax.get_lines()[2].set_label('$I_D$')
line.set_label('$I_G$')
ax.legend()
ax.set_ylim(top=1e-5, bottom=1e-13)
dpu.saveExternalPlot(fig, 'LHL1')

fig, (ax,) = dpu.makeDevicePlot('SubthresholdCurve', data_LHL2, data_LHL2[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'publication_mode':False, 'figureSizeOverride':(2,2.5)})
for data in data_LHL2:
    x_lines, y_lines, y_error = mplu.extractSweep(ax, data, 'both', x_data='gate voltage', y_data='gate current')
    for x,y in zip(x_lines, y_lines): 
        line = ax.plot(np.array(x), np.abs(y), color="#4FB99F", marker='o', markersize=2, linewidth=1)[0]
ax.get_lines()[2].set_label('$I_D$')
line.set_label('$I_G$')
ax.legend()
ax.set_ylim(top=1e-5, bottom=1e-13)
dpu.saveExternalPlot(fig, 'LHL2')

fig, (ax,) = dpu.makeDevicePlot('SubthresholdCurve', data_LHL3, data_LHL3[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'publication_mode':False, 'figureSizeOverride':(2,2.5)})
for data in data_LHL3:
    x_lines, y_lines, y_error = mplu.extractSweep(ax, data, 'both', x_data='gate voltage', y_data='gate current')
    for x,y in zip(x_lines, y_lines): 
        line = ax.plot(np.array(x), np.abs(y), color="#4FB99F", marker='o', markersize=2, linewidth=1)[0]
ax.get_lines()[2].set_label('$I_D$')
line.set_label('$I_G$')
ax.legend()
ax.set_ylim(top=1e-5, bottom=1e-13)
dpu.saveExternalPlot(fig, 'LHL3')

fig, (ax,) = dpu.makeDevicePlot('SubthresholdCurve', data_LHL4, data_LHL4[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'publication_mode':False, 'figureSizeOverride':(2,2.5)})
for data in data_LHL4:
    x_lines, y_lines, y_error = mplu.extractSweep(ax, data, 'both', x_data='gate voltage', y_data='gate current')
    for x,y in zip(x_lines, y_lines): 
        line = ax.plot(np.array(x), np.abs(y), color="#4FB99F", marker='o', markersize=2, linewidth=1)[0]
ax.get_lines()[2].set_label('$I_D$')
line.set_label('$I_G$')
ax.legend()
ax.set_ylim(top=1e-5, bottom=1e-13)
dpu.saveExternalPlot(fig, 'LHL4')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.362 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.577 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.472 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.636 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.472 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.593 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.366 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.574 s)
