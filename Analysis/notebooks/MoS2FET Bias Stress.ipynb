# %%
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../../../AutexysHost/source')
    
from utilities import DataLoggerUtility as dlu
from utilities import DataPlotterUtility as dpu
mplu = dpu.mplu
from utilities import FET_Modeling as fet_model
#from procedures import Device_History as DH

import numpy as np

# %%
data_original_performance = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=277, maxExperiment=277, maxRelativeIndex=1)
data_static_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'StaticBias.json', minExperiment=30, maxExperiment=30)
data_gate_sweeps = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=30, maxExperiment=30)

fig1, (ax1,) = dpu.makeDevicePlot('SubthresholdCurve', data_original_performance, data_original_performance[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2.3,2.5)})
ax1b = ax1.twinx()
mplu.plotTransferCurve(ax1b, data_original_performance[0], lineColor='#56638A', direction='forward', scaleCurrentBy=1e6)
ax1b.set_ylim(top=20.5)
dpu.saveExternalPlot(fig1, 'Combined_JM3B')

fig2, (ax2,) = dpu.makeDevicePlot('TransferCurve', data_gate_sweeps, data_gate_sweeps[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
ax2.set_yticks([0,4,8,12,16,20])
fig2.tight_layout()
dpu.saveExternalPlot(fig2, 'TransferCurveEditted_JM3B')

fig3, (ax3, ax3b, ax3c) = dpu.makeDevicePlot('StaticBias', data_static_bias, data_static_bias[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableGradient':True, 'publication_mode':True, 'figureSizeOverride':(2.5,2.4)})
ax3.set_xticks([0,1,2,3,4])
ax3.set_ylim(bottom = -1)
ax3.get_legend().get_title().set_fontsize('6')
dpu.saveExternalPlot(fig3, 'StaticBiasEditted_JM3B')
# Out:
# Plotting SubthresholdCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting SubthresholdCurve plot.
# Saving figures.
# Figures saved.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Plotting StaticBias plot.
# Saving figures.
# Figures saved.
# Finished plotting StaticBias plot.
# Saving figures.
# Figures saved.

# %%
data_n15V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=177, maxExperiment=177, minRelativeIndex=1)
data_n12V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=171, maxExperiment=171, minRelativeIndex=1)
data_n10V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=165, maxExperiment=165, minRelativeIndex=1)
data_n7V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=159, maxExperiment=159, minRelativeIndex=1)
data_n5V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=153, maxExperiment=153, minRelativeIndex=1)
data_n2V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=147, maxExperiment=147, minRelativeIndex=1)
data_0V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=141, maxExperiment=141, minRelativeIndex=1)
data_2V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=135, maxExperiment=135, minRelativeIndex=1)
data_5V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=129, maxExperiment=129, minRelativeIndex=1)
data_7V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=123, maxExperiment=123, minRelativeIndex=1)
data_10V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=117, maxExperiment=117, minRelativeIndex=1)
data_12V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=111, maxExperiment=111, minRelativeIndex=1)
data_15V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=105, maxExperiment=105, minRelativeIndex=1)

data_all = [data_n15V_bias[0],data_n12V_bias[0],data_n10V_bias[0],data_n7V_bias[0],data_n5V_bias[0],data_n2V_bias[0],data_0V_bias[0],data_2V_bias[0],data_5V_bias[0],data_7V_bias[0],data_10V_bias[0],data_12V_bias[0],data_15V_bias[0]]

splitColorMap = [
(0.6487658592848904, 0.23267973856209148, 0.16150711264898115, 1.0),
(0.7581084198385236, 0.2718954248366013, 0.18872741253364092, 1.0),
(0.8747404844290657, 0.3137254901960784, 0.21776239907727798, 1.0),
(0.9335640138408304, 0.37254901960784315, 0.2765859284890427, 1.0),
(0.9424221453287197, 0.4562091503267974, 0.373041138023837, 1.0),
(0.9507266435986159, 0.534640522875817, 0.4634678969627066, 1.0),
(0.1, 0.1, 0.1, 1.0),
(0.38682045367166473, 0.6277124183006536, 0.7946943483275664, 1.0),
(0.28347558631295655, 0.5649673202614379, 0.7600922722029989, 1.0),
(0.1732410611303345, 0.4980392156862745, 0.7231833910034603, 1.0),
(0.11441753171856978, 0.4392156862745098, 0.6643598615916956, 1.0),
(0.09916186082276048, 0.38065359477124183, 0.5757785467128028, 1.0),
(0.08485966935793925, 0.3257516339869281, 0.49273356401384083, 1.0),
]



fig1, (ax1,) = dpu.makeDevicePlot('TransferCurve', data_all, data_15V_bias[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':splitColorMap})

yvals, params, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(data_0V_bias[0]['Results']['vgs_data'][0], data_0V_bias[0]['Results']['id_data'][0], data_0V_bias[0]['runConfigs']['GateSweep']['drainVoltageSetPoint'])
V_T0 = fitted_model_parameters_kw['V_T']
print('V_T0: ' + '{:.2f} V'.format(V_T0))

data_all_fitted = []
V_T = {}
for deviceRun in data_all:
    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][0], deviceRun['Results']['id_data'][0], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'])
    data_all_fitted.append(fitted_vals)
    V_T[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['V_T']
    #ax1.plot(deviceRun['Results']['vgs_data'][0], 10**6 * np.array(fitted_vals), color='black')

fig2, (ax2,) = dpu.makeBlankPlot(figsize=(2,2))
ax2.set_xlabel('$V_{{GS}}$ (V)')
ax2.set_ylabel('$\\Delta V_{{T}}$ (V)')
ax2.plot([-17, 17], [0, 0], color='black', linewidth=0.5)
index = 0
for key,val in V_T.items():
    ax2.plot([key], [val - V_T0], color=splitColorMap[index], marker='o', markersize=3)
    index += 1
ax2.set_xlim((-17,17))
dpu.saveExternalPlot(fig2, 'DeltaVT_JM3B')
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# V_T0: 4.97 V
# Saving figures.
# Figures saved.

# %%
data_n15V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=272, maxExperiment=272, minRelativeIndex=1)
data_n12V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=266, maxExperiment=266, minRelativeIndex=1)
data_n10V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=260, maxExperiment=260, minRelativeIndex=1)
data_n7V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=254, maxExperiment=254, minRelativeIndex=1)
data_n5V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=248, maxExperiment=248, minRelativeIndex=1)
data_n2V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=242, maxExperiment=242, minRelativeIndex=1)
data_0V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=236, maxExperiment=236, minRelativeIndex=1)
data_2V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=230, maxExperiment=230, minRelativeIndex=1)
data_5V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=224, maxExperiment=224, minRelativeIndex=1)
data_7V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=218, maxExperiment=218, minRelativeIndex=1)
data_10V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=212, maxExperiment=212, minRelativeIndex=1)
data_12V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=206, maxExperiment=206, minRelativeIndex=1)
data_15V_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=200, maxExperiment=200, minRelativeIndex=1)

data_all = [data_n15V_bias[0],data_n12V_bias[0],data_n10V_bias[0],data_n7V_bias[0],data_n5V_bias[0],data_n2V_bias[0],data_2V_bias[0],data_5V_bias[0],data_7V_bias[0],data_10V_bias[0],data_12V_bias[0],data_15V_bias[0],data_0V_bias[0]]

splitColorMap = [
(0.6487658592848904, 0.23267973856209148, 0.16150711264898115, 1.0),
(0.7581084198385236, 0.2718954248366013, 0.18872741253364092, 1.0),
(0.8747404844290657, 0.3137254901960784, 0.21776239907727798, 1.0),
(0.9335640138408304, 0.37254901960784315, 0.2765859284890427, 1.0),
(0.9424221453287197, 0.4562091503267974, 0.373041138023837, 1.0),
(0.9507266435986159, 0.534640522875817, 0.4634678969627066, 1.0),

(0.38682045367166473, 0.6277124183006536, 0.7946943483275664, 1.0),
(0.28347558631295655, 0.5649673202614379, 0.7600922722029989, 1.0),
(0.1732410611303345, 0.4980392156862745, 0.7231833910034603, 1.0),
(0.11441753171856978, 0.4392156862745098, 0.6643598615916956, 1.0),
(0.09916186082276048, 0.38065359477124183, 0.5757785467128028, 1.0),
(0.08485966935793925, 0.3257516339869281, 0.49273356401384083, 1.0),
    
(0.1, 0.1, 0.1, 1.0),
]


# === Plot Data ===
fig1, (ax1,) = dpu.makeDevicePlot('TransferCurve', data_all, data_15V_bias[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':splitColorMap, 'publication_mode':True})
ax1.set_xlim(left=-19)
ax1.set_xticks([-10,0,10,20])
dpu.saveExternalPlot(fig1, 'ZOOM_JM3B')

#fig1b, (ax1b,) = dpu.makeDevicePlot('SubthresholdCurve', data_all, data_15V_bias[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':splitColorMap, 'publication_mode':True})

#specificData = data_n15V_bias[0]
#yvals, params, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(specificData['Results']['vgs_data'][0], specificData['Results']['id_data'][0], specificData['runConfigs']['GateSweep']['drainVoltageSetPoint'])
#fig3, ax3 = dpu.makeBlankPlot()
#ax3.plot(specificData['Results']['vgs_data'][0], 10**6 * np.array(yvals), color='black')
#ax3.plot(specificData['Results']['vgs_data'][0], 10**6 * np.array(specificData['Results']['id_data'][0]), color='blue', marker='o')


# === Extract Metrics ===
V_T0 = 0
V_T = {}
SS = {}
g_m = {}
for deviceRun in data_all:
    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][0], deviceRun['Results']['id_data'][0], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'])
    V_T[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['V_T']
    SS[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['SS_mV_dec']
    g_m[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['g_m_max']
    if(deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint'] == 0):
        V_T0 = fitted_model_parameters_kw['V_T']
        print('V_T0: ' + '{:.2f} V'.format(V_T0))
    #ax1.plot(deviceRun['Results']['vgs_data'][0], 10**6 * np.array(fitted_vals), color='black')
    

# === Delta V_T Plot ===    
fig2, (ax2,) = dpu.makeBlankPlot(figsize=(2,2))
ax2.set_xlabel('$V_{{GS}}$ (V)')
ax2.set_ylabel('$\\Delta V_{{T}}$ (V)')
ax2.plot([-17, 17], [0, 0], color='black', linewidth=0.5)
index = 0
for key,val in V_T.items():
    ax2.plot([key], [val - V_T0], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax2.set_xlim((-17,17))
dpu.saveExternalPlot(fig2, 'DeltaVT_JM3B')


# === N_it Plot ===
q = 1.602177e-19 # C
t_ox = 90e-7 # cm
eps_sio2 = (3.9 * 8.854187e-14) # F/cm
C_ox = (eps_sio2 / t_ox) #F/cm^2

fig3, (ax3,) = dpu.makeBlankPlot(figsize=(2,2))
ax3.set_xlabel('$V_{{GS}}$ (V)')
ax3.set_ylabel('$N_{{it}}$ Filled ($10^{{12}}$ $cm^{{-2}}$)')
index = 0
for key,val in V_T.items(): #SS.items(), g_m.items()
    ax3.plot([key], [abs((val-V_T0)*C_ox)/q  / (10**12)], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax3.set_xlim((-17,17))
dpu.saveExternalPlot(fig3, 'N_it_JM3B')
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# V_T0: 7.15 V
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
data_all = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM3/B/53-54', 'GateSweep.json', minExperiment=277, maxExperiment=277, minRelativeIndex=1)

splitColorMap = [
(0.554002306805075, 0.19869281045751633, 0.13791618608227604, 1.0),
(0.6633448673587082, 0.23790849673202613, 0.1651364859669358, 1.0),    
(0.7726874279123414, 0.2771241830065359, 0.19235678585159555, 1.0),
(0.8747404844290657, 0.3137254901960784, 0.21776239907727798, 1.0),
(0.9335640138408304, 0.37254901960784315, 0.2765859284890427, 1.0),
(0.9413148788927336, 0.4457516339869281, 0.3609842368319877, 1.0),
(0.9496193771626298, 0.5241830065359475, 0.4514109957708572, 1.0),
(0.957923875432526, 0.6026143790849674, 0.5418377547097271, 1.0),

(0.1, 0.1, 0.1, 1.0),    
    
(0.47638600538254516, 0.6820915032679739, 0.8246828143021915, 1.0),
(0.37304113802383676, 0.6193464052287581, 0.7900807381776239, 1.0),
(0.2696962706651288, 0.5566013071895425, 0.7554786620530566, 1.0),
(0.1732410611303345, 0.4980392156862745, 0.7231833910034603, 1.0),
(0.11441753171856978, 0.4392156862745098, 0.6643598615916956, 1.0),
(0.10106881968473663, 0.3879738562091503, 0.5868512110726644, 1.0),
(0.08676662821991542, 0.3330718954248366, 0.5038062283737025, 1.0),
(0.07246443675509419, 0.27816993464052286, 0.4207612456747405, 1.0),
    
]


# === Plot Data ===
fig1, (ax1,) = dpu.makeDevicePlot('TransferCurve', data_all, data_all[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':splitColorMap, 'publication_mode':True})
ax1.set_xlim(left=-17.5)
ax1.set_xticks([-10,0,10,20])
dpu.saveExternalPlot(fig1, 'ZOOM_JM3B')



# === Extract Metrics ===
V_T0 = 0
V_T = {}
SS = {}
g_m = {}
for deviceRun in data_all:
    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][0], deviceRun['Results']['id_data'][0], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'])
    V_T[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['V_T']
    SS[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['SS_mV_dec']
    g_m[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['g_m_max']
    if(deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint'] == 0):
        V_T0 = fitted_model_parameters_kw['V_T']
        print('V_T0: ' + '{:.2f} V'.format(V_T0))
    #ax1.plot(deviceRun['Results']['vgs_data'][0], 10**6 * np.array(fitted_vals), color='black')
    

# === Delta V_T Plot ===    
fig2, (ax2,) = dpu.makeBlankPlot(figsize=(2,2))
ax2.set_xlabel('$V_{{GS}}$ (V)')
ax2.set_ylabel('$\\Delta V_{{T}}$ (V)')
ax2.plot([-22, 22], [0, 0], color='black', linewidth=0.5)
index = 0
for key,val in V_T.items():
    ax2.plot([key], [val - V_T0], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax2.set_xlim((-22,22))
dpu.saveExternalPlot(fig2, 'DeltaVT_JM3B')
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# V_T0: 5.64 V
# Saving figures.
# Figures saved.

# %%
data_original_performance = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=14, maxExperiment=14, maxRelativeIndex=0)
data_static_bias = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'StaticBias.json', minExperiment=48, maxExperiment=48)
data_gate_sweeps = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=48, maxExperiment=48)
#data_gate_sweeps = [data_gate_sweeps[0], data_gate_sweeps[-1]]

fig1, (ax1,) = dpu.makeDevicePlot('SubthresholdCurve', data_original_performance, data_original_performance[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2.4,2.5), 'colorsOverride':['#555555']})
#ax1.plot([-3.4, -2.8], [10**-10, 10**-8], color='black', lw=0.75, ls='--') ## 300 mV/dec SS line
ax1.set_ylim(bottom=5e-12)
ax1b = ax1.twinx()
mplu.plotTransferCurve(ax1b, data_original_performance[0], lineColor='#EE7539', direction='forward', scaleCurrentBy=1e6)
ax1b.set_ylim(top=22.8)
ax1b.set_ylabel('$I_{D}$ ($\\mu$A)')
#ax1b.plot([1.9, 2.9], [11, 15], color='black', lw=0.75, ls='--')
dpu.saveExternalPlot(fig1, 'Combined_JM4C_34_35')

fig2, (ax2,) = dpu.makeDevicePlot('TransferCurve', data_gate_sweeps, data_gate_sweeps[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'reverse', 'publication_mode':True, 'colorsOverride':('white_blue_black', 0.7, 0.15)})
ax2.set_yticks([0,4,8,12,16,20])
ax2.set_xticks([-5,-3,-1,1,3,5])
fig2.tight_layout()
dpu.saveExternalPlot(fig2, 'TransferCurveEditted_JM4C_34_35')

fig3, (ax3, ax3b, ax3c) = dpu.makeDevicePlot('StaticBias', data_static_bias, data_static_bias[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableGradient':False, 'publication_mode':True, 'figureSizeOverride':(2.5,2.4), 'colorsOverride':('white_blue_black', 0.7, 0.15)})
ax3.set_ylim(bottom = -1)
ax3.get_legend().get_title().set_fontsize('6')
dpu.saveExternalPlot(fig3, 'StaticBiasEditted_JM4C_34_35')

fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(data_original_performance[0]['Results']['vgs_data'][0], data_original_performance[0]['Results']['id_data'][0], data_original_performance[0]['runConfigs']['GateSweep']['drainVoltageSetPoint'])
print('SS: ' + str(fitted_model_parameters_kw['SS_mV_dec'])) 
print('g_m_max: ' + str(fitted_model_parameters_kw['g_m_max']))   
print('V_T: ' + str(fitted_model_parameters_kw['V_T'])) 

fig4, (ax4,) = dpu.makeDevicePlot('TransferCurve', [data_gate_sweeps[1]], data_gate_sweeps[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'reverse', 'publication_mode':True, 'colorsOverride':[ax3.lines[0].get_color()], 'figureSizeOverride':(1.15,1.4)})
ax4.set_yticks([])
ax4.set_xticks([])
fig4.tight_layout()
dpu.saveExternalPlot(fig2, 'TransferCurveSpecific_JM4C_34_35')
# Out:
# Plotting SubthresholdCurve plot.
# Finished plotting SubthresholdCurve plot.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Plotting TransferCurve plot.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Plotting StaticBias plot.
# Finished plotting StaticBias plot.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# SS: 303.0221586661293
# g_m_max: 4.4364494224937875e-06
# V_T: -1.0147619840372775
# Plotting TransferCurve plot.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
data_all = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=20, maxExperiment=20, minRelativeIndex=0)

splitColorMap = [
#(0.6487658592848904, 0.23267973856209148, 0.16150711264898115, 1.0),
(0.7581084198385236, 0.2718954248366013, 0.18872741253364092, 1.0),
(0.8747404844290657, 0.3137254901960784, 0.21776239907727798, 1.0),
(0.9335640138408304, 0.37254901960784315, 0.2765859284890427, 1.0),
(0.9424221453287197, 0.4562091503267974, 0.373041138023837, 1.0),
#(0.9507266435986159, 0.534640522875817, 0.4634678969627066, 1.0),

(0.1, 0.1, 0.1, 1.0),    
    
#(0.38682045367166473, 0.6277124183006536, 0.7946943483275664, 1.0),
(0.28347558631295655, 0.5649673202614379, 0.7600922722029989, 1.0),
#(0.1732410611303345, 0.4980392156862745, 0.7231833910034603, 1.0),
#(0.11441753171856978, 0.4392156862745098, 0.6643598615916956, 1.0),
#(0.09916186082276048, 0.38065359477124183, 0.5757785467128028, 1.0),
#(0.08485966935793925, 0.3257516339869281, 0.49273356401384083, 1.0),
    
]

# === Plot Data ===
fig1, (ax1,) = dpu.makeDevicePlot('TransferCurve', data_all, data_all[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':splitColorMap, 'publication_mode':True})
#ax1.set_xlim(left=-17.5)
#ax1.set_xticks([-10,0,10,20])
#dpu.saveExternalPlot(fig1, 'ZOOM_JM4C_34_35')



# === Extract Metrics ===
V_T0 = 0
V_T = {}
SS = {}
g_m = {}
for deviceRun in data_all:
    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][0], deviceRun['Results']['id_data'][0], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'])
    V_T[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['V_T']
    SS[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['SS_mV_dec']
    g_m[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['g_m_max']
    if(deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint'] == 0):
        V_T0 = fitted_model_parameters_kw['V_T']
        print('V_T0: ' + '{:.2f} V'.format(V_T0))
    #ax1.plot(deviceRun['Results']['vgs_data'][0], 10**6 * np.array(fitted_vals), color='black')

print(('g_m: ' + '[' + (', '.join(['{:.2e}']*len(g_m.values()))).format(*list(g_m.values())) + ']') )
print(('SS: ' + '[' + (', '.join(['{:.2f}']*len(SS.values()))).format(*list(SS.values())) + ']') )

# === Delta V_T Plot ===    
fig2, (ax2,) = dpu.makeBlankPlot(figsize=(2,2))
ax2.set_xlabel('$V_{{GS}}$ (V)')
ax2.set_ylabel('$\\Delta V_{{T}}$ (V)')
ax2.plot([-5, 5], [0, 0], color='black', linewidth=0.5)
index = 0
for key,val in V_T.items():
    ax2.plot([key], [val - V_T0], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax2.set_xlim((-5,5))
dpu.saveExternalPlot(fig2, 'DeltaVT_JM4C_34_35')

# === N_it Plot ===
q = 1.602177e-19 # C
t_ox = 25e-7 # cm
eps_sio2 = (3.9 * 8.854187e-14) # F/cm
C_ox = (eps_sio2 / t_ox) #F/cm^2

fig3, (ax3,) = dpu.makeBlankPlot(figsize=(2,2))
ax3.set_xlabel('$V_{{GS}}$ (V)')
ax3.set_ylabel('$N_{{it}}$ Filled ($10^{{12}}$ $cm^{{-2}}$)')
index = 0
for key,val in V_T.items():
    ax3.plot([key], [abs((val-V_T0)*C_ox)/q  / (10**12)], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax3.set_xlim((-5,5))
dpu.saveExternalPlot(fig3, 'N_it_JM4C_34_35')
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# V_T0: -1.22 V
# g_m: [4.18e-06, 4.30e-06, 4.35e-06, 4.31e-06, 4.27e-06, 4.39e-06]
# SS: [445.88, 147.23, 178.20, 220.68, 264.97, 304.04]
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
#data_all = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=32, maxExperiment=32, minRelativeIndex=0)
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# V_T0: -1.10 V
# g_m: [3.84e-06, 4.15e-06, 4.25e-06, 4.16e-06, 4.07e-06]
# SS: [217.09, 226.18, 245.97, 295.06, 346.34]
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
data_all = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=38, maxExperiment=38, minRelativeIndex=0)

splitColorMap = list(reversed([
(0.6487658592848904, 0.23267973856209148, 0.16150711264898115, 1.0),
#(0.7581084198385236, 0.2718954248366013, 0.18872741253364092, 1.0),
(0.8747404844290657, 0.3137254901960784, 0.21776239907727798, 1.0),
(0.9335640138408304, 0.37254901960784315, 0.2765859284890427, 1.0),
#(0.9424221453287197, 0.4562091503267974, 0.373041138023837, 1.0),
(0.9507266435986159, 0.534640522875817, 0.4634678969627066, 1.0),

(0.1, 0.1, 0.1, 1.0),    
    
(0.38682045367166473, 0.6277124183006536, 0.7946943483275664, 1.0),
#(0.28347558631295655, 0.5649673202614379, 0.7600922722029989, 1.0),
(0.1732410611303345, 0.4980392156862745, 0.7231833910034603, 1.0),
(0.11441753171856978, 0.4392156862745098, 0.6643598615916956, 1.0),
#(0.09916186082276048, 0.38065359477124183, 0.5757785467128028, 1.0),
(0.08485966935793925, 0.3257516339869281, 0.49273356401384083, 1.0),
    
]))

# === Plot Data ===
fig1, (ax1,) = dpu.makeDevicePlot('TransferCurve', data_all, data_all[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':splitColorMap, 'publication_mode':True})
#ax1.set_xlim(left=-17.5)
ax1.set_xticks([-5,-3,-1,1,3,5])
dpu.saveExternalPlot(fig1, 'ZOOM_JM4C_34_35')



# === Extract Metrics ===
V_T0 = 0
V_T = {}
SS = {}
g_m = {}
for deviceRun in data_all:
    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][1], deviceRun['Results']['id_data'][1], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'])
    V_T[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['V_T']
    SS[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['SS_mV_dec']
    g_m[deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint']] = fitted_model_parameters_kw['g_m_max']
    if(deviceRun['runConfigs']['StaticBias']['gateVoltageSetPoint'] == 0):
        V_T0 = fitted_model_parameters_kw['V_T']
        print('V_T0: ' + '{:.2f} V'.format(V_T0))
    #ax1.plot(deviceRun['Results']['vgs_data'][0], 10**6 * np.array(fitted_vals), color='black')

print(('g_m: ' + '[' + (', '.join(['{:.2e}']*len(g_m.values()))).format(*list(g_m.values())) + ']') )
print(('SS: ' + '[' + (', '.join(['{:.2f}']*len(SS.values()))).format(*list(SS.values())) + ']') )

# === Delta V_T Plot ===    
fig2, (ax2,) = dpu.makeBlankPlot(figsize=(2,2))
ax2.set_xlabel('$V_{{GS}}$ (V)')
ax2.set_ylabel('$\\Delta V_{{T}}$ (V)')
ax2.plot([-5, 5], [0, 0], color='black', linewidth=0.5)
index = 0
for key,val in V_T.items():
    ax2.plot([key], [val - V_T0], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax2.set_xlim((-5,5))
dpu.saveExternalPlot(fig2, 'DeltaVT_JM4C_34_35')

# === N_it Plot ===
q = 1.602177e-19 # C
t_ox = 25e-7 # cm
eps_sio2 = (3.9 * 8.854187e-14) # F/cm
C_ox = (eps_sio2 / t_ox) #F/cm^2

fig3, (ax3,) = dpu.makeBlankPlot(figsize=(2,2))
ax3.set_xlabel('$V_{{GS}}$ (V)')
ax3.set_ylabel('$N_{{it}}$ Filled ($10^{{12}}$ $cm^{{-2}}$)')
index = 0
for key,val in V_T.items():
    ax3.plot([key], [abs((val-V_T0)*C_ox)/q  / (10**12)], color=splitColorMap[index], marker='o', markersize=4)
    index += 1
ax3.set_xlim((-5,5))
dpu.saveExternalPlot(fig3, 'N_it_JM4C_34_35')
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# V_T0: -0.30 V
# g_m: [4.42e-06, 4.21e-06, 4.30e-06, 4.32e-06, 4.29e-06, 4.22e-06, 4.22e-06, 4.15e-06, 4.20e-06]
# SS: [377.45, 285.38, 287.48, 267.07, 253.47, 216.39, 222.23, 215.39, 208.69]
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
data_orig_D1_2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D3_4 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/3-4', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D3_6 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/3-6', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D7_11 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/7-11', 'GateSweep.json', minExperiment=26, maxExperiment=26, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D24_25 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/24-25', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D28_29 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/28-29', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D43_44 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/43-44', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=0, maxRelativeIndex=0)
data_orig = [data_orig_D1_2[0], data_orig_D3_4[0], data_orig_D3_6[0], data_orig_D7_11[0], data_orig_D24_25[0], data_orig_D28_29[0], data_orig_D43_44[0]]

data_ALD_D1_2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D3_4 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/3-4', 'GateSweep.json', minExperiment=14, maxExperiment=14, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D3_6 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/3-6', 'GateSweep.json', minExperiment=9, maxExperiment=9, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D7_11 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/7-11', 'GateSweep.json', minExperiment=43, maxExperiment=43, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD2_D7_11 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/7-11', 'GateSweep.json', minExperiment=40, maxExperiment=40, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D24_25 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/24-25', 'GateSweep.json', minExperiment=10, maxExperiment=10, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D28_29 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/28-29', 'GateSweep.json', minExperiment=15, maxExperiment=15, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD_D43_44 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/43-44', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=0, maxRelativeIndex=0)
data_ALD = [data_ALD_D1_2[0], data_ALD_D3_4[0], data_ALD_D3_6[0], data_ALD_D7_11[0], data_ALD_D24_25[0], data_ALD_D28_29[0], data_ALD_D43_44[0]]


figA1, axA1 = dpu.makeDevicePlot('TransferCurve', [data_orig_D1_2[0], data_ALD_D1_2[0]], data_orig_D1_2[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA2, axA2 = dpu.makeDevicePlot('TransferCurve', [data_orig_D3_4[0], data_ALD_D3_4[0]], data_orig_D3_4[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA3, axA3 = dpu.makeDevicePlot('TransferCurve', [data_orig_D3_6[0], data_ALD_D3_6[0]], data_orig_D3_6[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA4, axA4 = dpu.makeDevicePlot('TransferCurve', [data_orig_D7_11[0], data_ALD_D7_11[0]], data_orig_D7_11[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA5, axA5 = dpu.makeDevicePlot('TransferCurve', [data_orig_D24_25[0], data_ALD_D24_25[0]], data_orig_D24_25[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA6, axA6 = dpu.makeDevicePlot('TransferCurve', [data_orig_D28_29[0], data_ALD_D28_29[0]], data_orig_D28_29[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
figA7, axA7 = dpu.makeDevicePlot('TransferCurve', [data_orig_D43_44[0], data_ALD_D43_44[0]], data_orig_D43_44[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
#figA8, axA8 = dpu.makeDevicePlot('TransferCurve', [data_orig_D7_11[0], data_ALD2_D7_11[0]], data_orig_D7_11[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True, 'figureSizeOverride':(2,2.5)})

figB1, axB1 = dpu.makeChipPlot('ChipTransferCurve', data_orig[0]['Identifiers'], recentRunChipHistory=data_orig, specificRunChipHistory=data_orig, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB2, axB2 = dpu.makeChipPlot('ChipTransferCurve', data_ALD[0]['Identifiers'], recentRunChipHistory=data_ALD, specificRunChipHistory=data_ALD, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB3, axB3 = dpu.makeChipPlot('ChipTransferCurve', data_ALD[0]['Identifiers'], recentRunChipHistory=[*data_orig, *data_ALD], specificRunChipHistory=[*data_orig, *data_ALD], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB4, axB4 = dpu.makeChipPlot('ChipSubthresholdCurve', data_orig[0]['Identifiers'], recentRunChipHistory=data_orig, specificRunChipHistory=data_orig, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB5, axB5 = dpu.makeChipPlot('ChipSubthresholdCurve', data_ALD[0]['Identifiers'], recentRunChipHistory=data_ALD, specificRunChipHistory=data_ALD, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB6, axB6 = dpu.makeChipPlot('ChipSubthresholdCurve', data_ALD[0]['Identifiers'], recentRunChipHistory=[*data_orig, *data_ALD], specificRunChipHistory=[*data_orig, *data_ALD], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
# Out:
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Finished plotting TransferCurve plot.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.
# Saving figures.
# Figures saved.

# %%
# Code moved later in the notebook
# Out:
# Saving figures.
# Figures saved.

# %%
data_orig_D2_3 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/2-3', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D4_5 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/4-5', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D6_7 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/6-7', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D14_19 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/14-19', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D28_29 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/28-29', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D30_31 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/30-31', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D34_35 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/34-35', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D36_37 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/36-37', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D40_41 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/40-41', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D43_44 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/43-44', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D47_50 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/47-50', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D48_49 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/48-49', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig_D62_63 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/62-63', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_orig = [data_orig_D2_3[0], data_orig_D4_5[0], data_orig_D6_7[0], data_orig_D14_19[0], data_orig_D28_29[0], data_orig_D30_31[0], data_orig_D34_35[0], data_orig_D36_37[0], data_orig_D40_41[0], data_orig_D43_44[0], data_orig_D47_50[0], data_orig_D48_49[0], data_orig_D62_63[0]]

data_PMMA_D2_3 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/2-3', 'GateSweep.json', minExperiment=9, maxExperiment=9, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D4_5 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/4-5', 'GateSweep.json', minExperiment=11, maxExperiment=11, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D6_7 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/6-7', 'GateSweep.json', minExperiment=13, maxExperiment=13, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D14_19 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/14-19', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D28_29 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/28-29', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D30_31 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/30-31', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D34_35 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/34-35', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D36_37 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/36-37', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D40_41 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/40-41', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D43_44 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/43-44', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D47_50 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/47-50', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D48_49 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/48-49', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA_D62_63 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/62-63', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_PMMA = [data_PMMA_D2_3[0], data_PMMA_D4_5[0], data_PMMA_D6_7[0], data_PMMA_D14_19[0], data_PMMA_D28_29[0], data_PMMA_D30_31[0], data_PMMA_D34_35[0], data_PMMA_D36_37[0], data_PMMA_D40_41[0], data_PMMA_D43_44[0], data_PMMA_D47_50[0], data_PMMA_D48_49[0], data_PMMA_D62_63[0]]

figB1, axB1 = dpu.makeChipPlot('ChipTransferCurve', data_orig[0]['Identifiers'], recentRunChipHistory=data_orig, specificRunChipHistory=data_orig, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB2, axB2 = dpu.makeChipPlot('ChipTransferCurve', data_PMMA[0]['Identifiers'], recentRunChipHistory=data_PMMA, specificRunChipHistory=data_PMMA, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB3, axB3 = dpu.makeChipPlot('ChipTransferCurve', data_PMMA[0]['Identifiers'], recentRunChipHistory=[*data_orig, *data_PMMA], specificRunChipHistory=[*data_orig, *data_PMMA], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB4, axB4 = dpu.makeChipPlot('ChipSubthresholdCurve', data_orig[0]['Identifiers'], recentRunChipHistory=data_orig, specificRunChipHistory=data_orig, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB5, axB5 = dpu.makeChipPlot('ChipSubthresholdCurve', data_PMMA[0]['Identifiers'], recentRunChipHistory=data_PMMA, specificRunChipHistory=data_PMMA, mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
figB6, axB6 = dpu.makeChipPlot('ChipSubthresholdCurve', data_PMMA[0]['Identifiers'], recentRunChipHistory=[*data_orig, *data_PMMA], specificRunChipHistory=[*data_orig, *data_PMMA], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'forward', 'publication_mode':True})
# Out:
# Plotting ChipTransferCurve plot.
# Saving figures.
# Figures saved.
# Plotting ChipTransferCurve plot.
# Saving figures.
# Figures saved.
# Plotting ChipTransferCurve plot.
# Saving figures.
# Figures saved.
# Plotting ChipSubthresholdCurve plot.
# Saving figures.
# Figures saved.
# Plotting ChipSubthresholdCurve plot.
# Saving figures.
# Figures saved.
# Plotting ChipSubthresholdCurve plot.
# Saving figures.
# Figures saved.

# %%
data_Ambient = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'RapidBias.json', minExperiment=91, maxExperiment=91)
data_ALD = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'RapidBias.json', minExperiment=28, maxExperiment=28)
data_PMMA = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/6-7', 'RapidBias.json', minExperiment=33, maxExperiment=33)

fig1, ax1 = dpu.makeBlankPlot(figsize=(2,2.5))

color_Ambient = '#111111'
color_ALD = '#1CCEA7'
color_PMMA = '#351996'

timestamps_Ambient = np.array(data_Ambient[0]['Results']['timestamps'])-min(data_Ambient[0]['Results']['timestamps'])
timestamps_ALD = np.array(data_ALD[0]['Results']['timestamps'])-min(data_ALD[0]['Results']['timestamps'])
timestamps_PMMA = np.array(data_PMMA[0]['Results']['timestamps'])-min(data_PMMA[0]['Results']['timestamps'])

signal_vgs = np.array(data_ALD[0]['Results']['vgs_data'])/max(data_ALD[0]['Results']['vgs_data'])
signal_Ambient = np.array(data_Ambient[0]['Results']['id_data'])/max(data_Ambient[0]['Results']['id_data'])
signal_ALD = np.array(data_ALD[0]['Results']['id_data'])/max(data_ALD[0]['Results']['id_data'])
signal_PMMA = np.array(data_PMMA[0]['Results']['id_data'])/max(data_PMMA[0]['Results']['id_data'])

line_Ambient = ax1.plot(timestamps_Ambient, signal_Ambient, color=color_Ambient, marker='o', markersize=2, linewidth=1)[0]
line_ALD = ax1.plot(timestamps_ALD, signal_ALD, color=color_ALD, marker='o', markersize=2, linewidth=1)[0]
line_PMMA = ax1.plot(timestamps_PMMA, signal_PMMA, color=color_PMMA, marker='o', markersize=2, linewidth=1)[0]
line_vgs = ax1.plot(timestamps_ALD, signal_vgs, color='#333333', ls='--', linewidth=0.75)[0]


ax1.set_yticks([-1,0,1])
ax1.set_yticklabels(['$-$max','0','$+$max'])
ax1.set_xlabel('Time (s)')
ax1.set_ylabel('Signal (a.u.)')
ax1.legend([line_Ambient, line_ALD, line_PMMA, line_vgs], ['$Ambient$', '$Al_{2}O_{3}$','$PMMA$','$V_{GS}$'], loc='lower right', bbox_to_anchor=(1,0.05))

dpu.saveExternalPlot(fig1, 'RapidResponse_Comparison')
# Out:
# Saving figures.
# Figures saved.

# %%
data_Ambient1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'GateSweep.json', minExperiment=48, maxExperiment=48)
data_Ambient2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/3-6', 'GateSweep.json', minExperiment=16, maxExperiment=16)
data_Ambient3 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/20-31', 'GateSweep.json', minExperiment=14, maxExperiment=14)
data_Ambient = [data_Ambient1,data_Ambient2,data_Ambient3]

data_20nmALD1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/J/33-34', 'GateSweep.json', minExperiment=9, maxExperiment=9)
data_20nmALD = [data_20nmALD1]

data_40nmALD1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'GateSweep.json', minExperiment=13, maxExperiment=13)   # No VT shift
data_40nmALD2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/28-29', 'GateSweep.json', minExperiment=27, maxExperiment=27) # No VT shift
#data_40nmALD3 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'GateSweep.json', minExperiment=28, maxExperiment=28)
##data_40nmALD4 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/3-4', 'GateSweep.json', minExperiment=32, maxExperiment=32) # Large VT shift (device is 2.5 months old)
data_40nmALD = [data_40nmALD1, data_40nmALD2]

data_PMMA1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/43-44', 'GateSweep.json', minExperiment=9, maxExperiment=9)
data_PMMA2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/30-31', 'GateSweep.json', minExperiment=9, maxExperiment=9)
data_PMMA3 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/6-7', 'GateSweep.json', minExperiment=38, maxExperiment=38)
data_PMMA = [data_PMMA1,data_PMMA2,data_PMMA3]

data_all = [data_Ambient,data_20nmALD,data_40nmALD,data_PMMA]

# === Extract V_T Shifts ===
gm_region_length_overrides = [11,11,30,11]
gm_region_length_override = None
ss_region_length_override = None
drainCurrentForVTExtractions = [5e-6,5e-6,35e-6,5e-6]
#drainCurrentForVTExtractions = [5e-6,5e-6,None,5e-6]
delta_VT_Ambient = []
delta_VT_20nmALD = []
delta_VT_40nmALD = []
delta_VT_PMMA = []
for i in range(len(data_all)):
    chip_data = data_all[i]
    for experiment in chip_data:
        #gm_region_length_override = gm_region_length_overrides[i]
        gateVoltages = [deviceRun['Results']['vgs_data'][1] for deviceRun in experiment]
        drainCurrents = [deviceRun['Results']['id_data'][1] for deviceRun in experiment]
        drainCurrentForVTExtraction = drainCurrentForVTExtractions[i]
        metrics = fet_model.FET_Metrics_Multiple(gateVoltages, drainCurrents, gm_region_length_override=gm_region_length_override, ss_region_length_override=ss_region_length_override, extraction_mode_VT=['byDrainCurrent', drainCurrentForVTExtraction])

        V_T = metrics['V_T']
        
        #V_T = []
        #for deviceRun in experiment:
        #    fitted_vals, fitted_model_parameters, fitted_model_parameters_kw = fet_model.NMOSFET_Fit(deviceRun['Results']['vgs_data'][1], deviceRun['Results']['id_data'][1], deviceRun['runConfigs']['GateSweep']['drainVoltageSetPoint'], gm_region_length_override=gm_region_length_override, ss_region_length_override=ss_region_length_override)
        #    V_T.append(fitted_model_parameters_kw['V_T'])
        
        delta_VT = []
        if(experiment in data_Ambient):
            delta_VT = delta_VT_Ambient
        elif(experiment in data_20nmALD):
            delta_VT = delta_VT_20nmALD
        elif(experiment in data_40nmALD):
            delta_VT = delta_VT_40nmALD
        elif(experiment in data_PMMA):
            delta_VT = delta_VT_PMMA
        else:
            raise NotImplmentedError('Data loaded could not be verified to be from Ambient, ALD, or PMMA.')
        
        # Take VT shift to be the second VT minus the intial VT    
        delta_VT.append(V_T[1] - V_T[0])
        

print('Ambient VT shift: ' + str(delta_VT_Ambient))
print('20nm ALD VT shift: ' + str(delta_VT_20nmALD))
print('40nm ALD VT shift: ' + str(delta_VT_40nmALD))
print('PMMA VT shift: ' + str(delta_VT_PMMA))

delta_VT_mean_Ambient = np.mean(delta_VT_Ambient)
delta_VT_mean_20nmALD = np.mean(delta_VT_20nmALD)
delta_VT_mean_40nmALD = np.mean(delta_VT_40nmALD)
delta_VT_mean_PMMA = np.mean(delta_VT_PMMA)

delta_VT_std_Ambient = np.std(delta_VT_Ambient)
delta_VT_std_20nmALD = np.std(delta_VT_20nmALD)
delta_VT_std_40nmALD = np.std(delta_VT_40nmALD)
delta_VT_std_PMMA = np.std(delta_VT_PMMA)

# === Plot ===

fig1, ax1 = dpu.makeBlankPlot(figsize=(2,2.5))

color_Ambient = '#111111'
color_ALD = '#1CCEA7'
color_PMMA = '#351996'

marker_size = 3
cap_size = 3
cap_thick = 1
err_linewidth = 1

ax1.errorbar([10], [delta_VT_mean_Ambient], yerr=delta_VT_std_Ambient, color=color_Ambient, capsize=cap_size, capthick=cap_thick, elinewidth=err_linewidth, marker='D', markersize=marker_size)
ax1.errorbar([150], [delta_VT_mean_PMMA], yerr=delta_VT_std_PMMA, color=color_PMMA, capsize=cap_size, capthick=cap_thick, elinewidth=err_linewidth, marker='D', markersize=marker_size)
ax1.errorbar([40], [delta_VT_mean_40nmALD], yerr=delta_VT_std_40nmALD, color=color_ALD, capsize=cap_size, capthick=cap_thick, elinewidth=err_linewidth, marker='D', markersize=marker_size)
ax1.errorbar([20], [delta_VT_mean_20nmALD], yerr=delta_VT_std_20nmALD, color=color_ALD, capsize=cap_size if(len(delta_VT_20nmALD) > 1) else 0, capthick=cap_thick, elinewidth=err_linewidth, marker='D', markersize=marker_size)

#ax1.plot([40], [delta_VT_mean_ALD], color=color_ALD, marker='D', markersize=marker_size)
    
ax1.plot([0.1, 10**5], [delta_VT_mean_Ambient+delta_VT_std_Ambient]*2, color='#111111', alpha=0.2, linewidth=cap_thick)
ax1.plot([0.1, 10**5], [delta_VT_mean_Ambient-delta_VT_std_Ambient]*2, color='#111111', alpha=0.2, linewidth=cap_thick)
#ax1.plot([0.1, 10**5], [delta_VT_mean_Ambient]*2, color='#111111', alpha=0.2, linewidth=5)
         
ax1.set_xscale('log')
ax1.set_ylim(bottom = -0.15)
ax1.set_xlim(left=2, right=3*10**4)

ax1.set_xticklabels(['','','10 nm','100 nm','1 $\\mu$m','10 $\\mu$m'], y=-0.03, va='center')

ax1.set_xlabel('Capping Thickness')
ax1.set_ylabel('$\\Delta V_{{T}}$ (V)')

dpu.saveExternalPlot(fig1, 'Thickness_Comparison')



# === Data Comparison ===
data_sb_Ambient1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/C/34-35', 'StaticBias.json', minExperiment=48, maxExperiment=48)
data_sb_ALD1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/D/1-2', 'StaticBias.json', minExperiment=13, maxExperiment=13)
data_sb_PMMA1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/MoS2FET/JM4/H/43-44', 'StaticBias.json', minExperiment=9, maxExperiment=9)

# normalize
max_current = np.max([run['Results']['id_data'] for run in data_sb_Ambient1])
for deviceRun in data_sb_Ambient1:
    deviceRun['Results']['id_data'] = np.array(deviceRun['Results']['id_data'])/max_current*10**-6
max_current = np.max([run['Results']['id_data'] for run in data_sb_ALD1])
for deviceRun in data_sb_ALD1:
    deviceRun['Results']['id_data'] = np.array(deviceRun['Results']['id_data'])/max_current*10**-6
max_current = np.max([run['Results']['id_data'] for run in data_sb_PMMA1])
for deviceRun in data_sb_PMMA1:
    deviceRun['Results']['id_data'] = np.array(deviceRun['Results']['id_data'])/max_current*10**-6

fig2, (ax2, ax2b, ax2c) = dpu.makeDevicePlot('StaticBias', data_sb_PMMA1, data_sb_PMMA1[0]['Identifiers'], mode_parameters={'enableLegend':True, 'publication_mode':True, 'figureSizeOverride':(2.5,2.4), 'colorsOverride':[color_PMMA]*4})

for deviceRun in data_sb_ALD1:
    deviceRun['Results']['timestamps'] = np.array(deviceRun['Results']['timestamps'])/3600
t0 = data_sb_ALD1[0]['Results']['timestamps'][0]
time_offsets = [deviceRun['Results']['timestamps'][0] - t0 for deviceRun in data_sb_ALD1]
for i in range(len(data_sb_ALD1)):
    mplu.plotStaticBias(ax2, data_sb_ALD1[i], color_ALD, time_offsets[i])
    
for deviceRun in data_sb_Ambient1:
    deviceRun['Results']['timestamps'] = np.array(deviceRun['Results']['timestamps'])/3600
t0 = data_sb_Ambient1[0]['Results']['timestamps'][0]
time_offsets = [deviceRun['Results']['timestamps'][0] - t0 for deviceRun in data_sb_Ambient1]
for i in range(len(data_sb_Ambient1)):
    mplu.plotStaticBias(ax2, data_sb_Ambient1[i], color_Ambient, time_offsets[i])

ax2.get_legend().get_title().set_fontsize('6')
ax2.set_ylabel('$I_D$/$I_{{max}}$ (a.u.)')
dpu.saveExternalPlot(fig2, 'Data_Comparison')
# Out:
# Ambient VT shift: [0.7575158685931256, 0.9190852723143401, 1.1075869529630111]
# 20nm ALD VT shift: [0.07027326103666187]
# 40nm ALD VT shift: [0.06735002318868766, 0.24519405256508353]
# PMMA VT shift: [1.5415873398483098, 1.3483512350664013, 1.3406373247124024]
# Saving figures.
# Figures saved. (Seconds elapsed: 0.3613419532775879)
# Plotting StaticBias plot.
# Finished plotting StaticBias plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.39444398880004883)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.39644312858581543)
