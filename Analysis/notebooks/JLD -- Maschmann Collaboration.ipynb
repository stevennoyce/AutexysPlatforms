# %%
import os
import sys

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../../../AutexysHost/source')
    
from utilities import DataLoggerUtility as dlu
from utilities import DataPlotterUtility as dpu
mplu = dpu.mplu
from utilities import FET_Modeling as fet_model
#from procedures import Device_History as DH

import numpy as np

dataA = []
dataB = []

# %%
print('----------------------------------------------------------------------------------------------------')
print('CHIP A - TOP')
# Out:
# ----------------------------------------------------------------------------------------------------
# CHIP A - TOP

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/4-20', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=0, maxRelativeIndex=0)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/4-20', 'GateSweep.json', minExperiment=17, maxExperiment=17, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA4-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5-20', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=0, maxRelativeIndex=0)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5-20', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/15-20', 'GateSweep.json', minExperiment=18, maxExperiment=18, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/15-20', 'GateSweep.json', minExperiment=21, maxExperiment=21, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA15-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/16-20', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/16-20', 'GateSweep.json', minExperiment=15, maxExperiment=15, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA16-20')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.523 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.713 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.528 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.935 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.549 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.574 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.560 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.963 s)

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/18,2-TL,BL', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/18,2-TL,BL', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA18-2-TLBL')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/18,2-TR,BR', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/18,2-TR,BR', 'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA18-2-TRBR')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.653 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.728 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.741 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.884 s)

# %%
print('CHIP A - BOTTOM')
# Out:
# CHIP A - BOTTOM

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-4um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-4um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-4um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-5um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-5um', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=0, maxRelativeIndex=0)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-5um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-6um', 'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=5, maxRelativeIndex=5)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-6um', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-6um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-7um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-7um', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-7um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-8um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-8um', 'GateSweep.json', minExperiment=10, maxExperiment=10, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-8um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-12um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/A/5,2-12um', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('SubthresholdCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataA.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannA5-2-12um')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.556 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.560 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.643 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.603 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.511 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.527 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.549 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.697 s)
# ...

# %%
print(str('\n').join(dataA))
# Out:
# D4-20,1.5706438e-06,1.0798419000000002e-06,7.198999999999999e-11,6.606950000000001e-10
# D5-20,9.221871299999998e-07,1.1296740999999998e-06,7.938000000000001e-11,1.78355e-10
# D15-20,9.66678539999999e-07,8.072454999999997e-09,3.0185000000000004e-11,5.976149999999999e-10
# D16-20,1.6210313999999998e-07,2.7556739999999996e-07,8.840000000000002e-12,4.545000000000001e-12
# D18,2-TL,BL,8.461208399999996e-08,5.7259151999999986e-08,3.695e-12,2.49e-12
# D18,2-TR,BR,2.1522435e-07,4.3114238e-08,4.09e-12,3.4900000000000003e-12
# D5,2-4um,2.1745891e-08,2.4860889999999977e-09,3.155000000000001e-12,6.950000000000002e-13
# D5,2-5um,1.0680057999999999e-07,3.679809999999999e-10,1.1248000000000001e-10,2.6899999999999996e-12
# D5,2-6um,5.4014403e-07,1.0459201e-06,1.99026e-09,4.71489e-09
# D5,2-7um,2.743805699999999e-07,3.5040072999999996e-07,1.0813500000000001e-10,3.02865e-10
# D5,2-8um,9.3334433e-07,5.9018491e-07,1.1218000000000001e-10,2.4887999999999997e-10
# ...

# %%
print('----------------------------------------------------------------------------------------------------')
print('CHIP B -- TOP')
# Out:
# ----------------------------------------------------------------------------------------------------
# CHIP B -- TOP

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/4-20', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/4-20', 'GateSweep.json', minExperiment=12, maxExperiment=12, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB4-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5-20', 'GateSweep.json', minExperiment=9, maxExperiment=9, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5-20', 'GateSweep.json', minExperiment=13, maxExperiment=13, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-TL,BL', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-TL,BL', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB8-20-TL-BL')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-TL,BR', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-TL,BR', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB8-20-TL-BR')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-20um', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/8,20-TR,BR', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB8-20-TR-BR')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.381 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.403 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.454 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.445 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.586 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.396 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.413 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.367 s)
# [PLOT]: Plotting TransferCurve plot.
# ...

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/14-20', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/14-20', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB14-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/15-20', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/15-20', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB15-20')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-4um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-4um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-20-4um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-6um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-6um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-20-6um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-8um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,20-8um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-20-8um')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.503 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.477 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.470 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.440 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.447 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.465 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.376 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.392 s)
# [PLOT]: Plotting TransferCurve plot.
# ...

# %%
print('CHIP B -- BOTTOM')
# Out:
# CHIP B -- BOTTOM

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/15-2', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/15-2', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB15-2')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/16-2', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/16-2', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB16-2')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TL,BL', 'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TL,BL', 'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=0, maxRelativeIndex=0)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-2-TL-BL')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TL,BR', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TL,BR', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-2-TL-BR')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TR,BR', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/18,2-TR,BR', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB18-2-TR-BR')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.500 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.468 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.585 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.501 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.573 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.493 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.499 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.510 s)
# [PLOT]: Plotting TransferCurve plot.
# ...

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-4um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-4um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-4um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-5um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-5um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-5um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-6um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-6um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-6um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-7um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-7um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-7um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-8um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-8um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-8um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-10um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-10um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-10um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-12um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/5,2-12um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB5-2-12um')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.470 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.442 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.518 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.616 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.399 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.343 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.471 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.366 s)
# [PLOT]: Plotting TransferCurve plot.
# ...

# %%
data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-4um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-4um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-4um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-5um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-5um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-5um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-6um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-6um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-6um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-7um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-7um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-7um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-8um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-8um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-8um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-10um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-10um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-10um')

data_before = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-12um', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=4, maxRelativeIndex=4)
data_after  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/CNT/JC1/B/10,2-12um', 'GateSweep.json', minExperiment=7, maxExperiment=7, minRelativeIndex=4, maxRelativeIndex=4)

fig1, axes1 = dpu.makeDevicePlot('TransferCurve', data_before+data_after, data_before[0]['Identifiers'], mode_parameters={'publication_mode':False, 'figureSizeOverride':(2,2.25), 'enableColorBar':True, 'enableLegend':True, 'legendLabels':['Before','After'], 'colorsOverride':('white_blue_black',0.8,0.15), 'xticks':[-6,-4,-2,0,2,4,6], })
dataB.append(f"D{data_before[0]['Identifiers']['device']},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 99)},{np.percentile(abs(np.array(data_before[0]['Results']['id_data'])), 5)},{np.percentile(abs(np.array(data_after[0]['Results']['id_data'])), 5)}")
dpu.saveExternalPlot(fig1, 'MaschmannB10-2-12um')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.382 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.405 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.523 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.495 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.426 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.444 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.378 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.378 s)
# [PLOT]: Plotting TransferCurve plot.
# ...

# %%
print(str('\n').join(dataB))
# Out:
# D4-20,0.0001,8.356615700000002e-05,3.8270165e-05,7.338477e-05
# D5-20,0.0001,0.0001,2.726364e-05,4.3817095000000004e-05
# D8,20-TL,BL,0.0001,7.2789642e-05,4.367492e-05,7.136037e-05
# D8,20-TL,BR,0.0001,7.789652099999999e-05,4.7519744999999995e-05,7.640373500000001e-05
# D8,20-20um,1.0961586e-05,1.0678442e-05,1.7604104999999999e-06,3.2723885e-06
# D14-20,4.4801807e-05,3.8961537e-06,7.356712e-06,3.140576500000001e-08
# D15-20,4.2202757e-05,5.7039952e-05,1.0946589999999999e-05,1.840954e-05
# D18,20-4um,4.1798303e-05,4.1275574e-05,1.695003e-06,6.875919000000001e-06
# D18,20-6um,2.7555174999999995e-05,1.6756457e-05,1.4224359999999999e-06,4.938677500000001e-06
# D18,20-8um,2.2802860999999998e-05,6.2873242e-06,7.650859500000001e-07,2.0678830000000003e-06
# D15-2,1.4518574999999998e-05,7.0143396999999995e-06,2.7899605e-07,1.1973675000000002e-06
# D16-2,1.5433169000000002e-05,1.3349548e-05,3.513775e-07,8.1187305e-07
# ...
