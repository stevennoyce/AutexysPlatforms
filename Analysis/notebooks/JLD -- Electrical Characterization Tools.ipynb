# %%
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('../../../AutexysHost/source')
    
import numpy as np    
    
from utilities import DataLoggerUtility as dlu
from utilities import DataPlotterUtility as dpu
mplu = dpu.mplu
from utilities import FET_Modeling as fet_model
#from procedures import Device_History as DH

#%config InlineBackend.figure_format = 'png'

# %%
print(' === MOSFET Comparison Figure === ')

color_Lakeshore = '#7363af' #purple
color_Signatone = '#9F3285' #magenta
color_Doherty   = '#4FB99F' #green
color_BluePCBv1 = '#1f77b4' #blue
color_RedPCBv1  = '#ed553b' #red
color_RedPCBv2  = '#ed553b' #red

# === Load Data ===
data_Signatone = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Signatone/IRF730/30-32', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_Doherty   = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Doherty/IRF730/30-32',   'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_BluePCBv1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/BluePCBv1/IRF730/30-32', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv1  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv1/IRF730/32-30',  'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv2  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=1, maxExperiment=1, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_BluePCBv1 + data_Doherty + data_Signatone + data_RedPCBv2), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':[color_BluePCBv1]*len(data_BluePCBv1)+[color_Doherty]*len(data_Doherty)+[color_Signatone]*len(data_Signatone)+[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['Blue PCB','Doherty','Signatone','Red PCB'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'MOSFET_Comparison')
# Out:
#  === MOSFET Comparison Figure ===
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 1.022 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.677 s)

# %%
print(' === MOSFET + 100k Resistor Comparison Figure === ')

color_Lakeshore = '#7363af' #purple
color_Signatone = '#9F3285' #magenta
color_Doherty   = '#4FB99F' #green
color_BluePCBv1 = '#1f77b4' #blue
color_RedPCBv1  = '#ed553b' #red

# === Load Data ===
data_Signatone = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Signatone/IRF730_100k/26-32', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_Doherty   = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Doherty/IRF730_100k/26-32',   'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=1, maxRelativeIndex=1)
data_BluePCBv1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/BluePCBv1/IRF730_100k/26-32', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv1  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv1/IRF730_100k/32-27',  'GateSweep.json', minExperiment=4, maxExperiment=4, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_BluePCBv1 + data_Doherty + data_Signatone + data_RedPCBv1), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':[color_BluePCBv1]*len(data_BluePCBv1)+[color_Doherty]*len(data_Doherty)+[color_Signatone]*len(data_Signatone)+[color_RedPCBv1]*len(data_RedPCBv1), 'legendLabels':['Blue PCB','Doherty','Signatone','Red PCB'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'MOSFET_100k_Comparison')
# Out:
#  === MOSFET + 100k Resistor Comparison Figure ===
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 1.002 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.910 s)

# %%
print(' === 100k Resistor Comparison Figure === ')

color_Lakeshore = '#7363af' #purple
color_Signatone = '#9F3285' #magenta
color_Doherty   = '#4FB99F' #green
color_BluePCBv1 = '#1f77b4' #blue
color_RedPCBv1  = '#ed553b' #red

# === Load Data ===
data_Signatone = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Signatone/100k/26-30', 'DrainSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=1, maxRelativeIndex=1)
data_Doherty   = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Doherty/100k/26-30',   'DrainSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_BluePCBv1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/BluePCBv1/100k/26-30', 'DrainSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv1  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv1/100k/27-30',  'DrainSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('OutputCurve', (data_BluePCBv1 + data_Doherty + data_Signatone + data_RedPCBv1), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_BluePCBv1]*len(data_BluePCBv1)+[color_Doherty]*len(data_Doherty)+[color_Signatone]*len(data_Signatone)+[color_RedPCBv1]*len(data_RedPCBv1), 'legendLabels':['Blue PCB','Doherty','Signatone','Red PCB'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper left', handlelength=1)
dpu.saveExternalPlot(figA1, '100k_Comparison')
# Out:
#  === 100k Resistor Comparison Figure ===
# [PLOT]: Plotting OutputCurve plot.
# [PLOT]: Finished plotting OutputCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.926 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.594 s)

# %%
print(' === MOSFET Gate Current Comparison Figure === ')

color_Lakeshore = '#7363af' #purple
color_Signatone = '#9F3285' #magenta
color_Doherty   = '#4FB99F' #green
color_BluePCBv1 = '#1f77b4' #blue
color_RedPCBv1  = '#ed553b' #red
color_RedPCBv2  = '#ed553b' #red

# === Load Data ===
data_Signatone = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Signatone/IRF730/30-32', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_Doherty   = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Doherty/IRF730/30-32',   'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_BluePCBv1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/BluePCBv1/IRF730/30-32', 'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv1  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv1/IRF730/32-30',  'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv2  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=1, maxExperiment=1, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('GateCurrent', (data_BluePCBv1 + data_Doherty + data_Signatone + data_RedPCBv2), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_BluePCBv1]*len(data_BluePCBv1)+[color_Doherty]*len(data_Doherty)+[color_Signatone]*len(data_Signatone)+[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['Blue PCB','Doherty','Signatone','Red PCB'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'MOSFET_GateCurrent_Comparison')

# === Plot without Red ===
figA1, (axA1,) = dpu.makeDevicePlot('GateCurrent', (data_BluePCBv1 + data_Doherty + data_Signatone), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_BluePCBv1]*len(data_BluePCBv1)+[color_Doherty]*len(data_Doherty)+[color_Signatone]*len(data_Signatone), 'legendLabels':['Blue PCB','Doherty','Signatone'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'MOSFET_GateCurrent_noRed_Comparison')
# Out:
#  === MOSFET Gate Current Comparison Figure ===
# Plotting GateCurrent plot.
# Finished plotting GateCurrent plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.9903349876403809)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.5668368339538574)
# Plotting GateCurrent plot.
# Finished plotting GateCurrent plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.872988224029541)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.3096280097961426)

# %%
color_RedPCBv1_allinternal = '#ed553b' #red
color_RedPCBv1_externalR = '#7363af' #purple
color_RedPCBv1_externalAmp = '#4FB99F' #green
#color_RedPCBv1_allinternal = '#1f77b4' #blue
#color_RedPCBv1_allinternal = '#9F3285' #magenta

# === Load Data ===
data_RedPCBv1_allinternal  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/RedBoard/Resistor/100k/8-9',  'DrainSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=0, maxRelativeIndex=0)
data_RedPCBv1_externalR    = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/RedBoard/Resistor/100k/8-9',  'DrainSweep.json', minExperiment=9, maxExperiment=9, minRelativeIndex=0, maxRelativeIndex=0)
data_RedPCBv1_externalAmp  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/RedBoard/Resistor/100k/8-9',  'DrainSweep.json', minExperiment=10, maxExperiment=10, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('OutputCurve', (data_RedPCBv1_allinternal + data_RedPCBv1_externalR + data_RedPCBv1_externalAmp), data_RedPCBv1_allinternal[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_RedPCBv1_allinternal]*len(data_RedPCBv1_allinternal)+[color_RedPCBv1_externalR]*len(data_RedPCBv1_externalR)+[color_RedPCBv1_externalAmp]*len(data_RedPCBv1_externalAmp), 'legendLabels':['All Internal','External R','External Amp + R'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper left', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_External_OpAmp_Comparison')
# Out:
# Plotting OutputCurve plot.
# Finished plotting OutputCurve plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.6888160705566406)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.3626749515533447)

# %%
color_RedPCB_1MOhm_RF = '#ed553b' #red
color_RedPCB_100MOhm_RF = '#7363af' #purple

# === Load Data ===
data_RedPCB_1MOhm_RF  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/RedBoard/NMOSFET/IRF730/32-30',  'GateSweep.json', minExperiment=58, maxExperiment=58, minRelativeIndex=0, maxRelativeIndex=0)
data_RedPCB_100MOhm_RF  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/RedBoard/NMOSFET/IRF730/32-30',  'GateSweep.json', minExperiment=86, maxExperiment=86, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_RedPCB_1MOhm_RF + data_RedPCB_100MOhm_RF), data_RedPCB_1MOhm_RF[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_RedPCB_1MOhm_RF]*len(data_RedPCB_1MOhm_RF)+[color_RedPCB_100MOhm_RF]*len(data_RedPCB_100MOhm_RF), 'legendLabels':['Internal TIA','External TIA'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper left', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_RFeedback_Comparison')
# Out:
# Plotting SubthresholdCurve plot.
# Finished plotting SubthresholdCurve plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.9952840805053711)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.5867588520050049)

# %%
color_RedPCBv1 = '#ed553b' #red
color_RedPCBv2 = '#7363af' #purple

# === Load Data ===
data_RedPCBv1  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv1/IRF730/32-30',  'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv2  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=1, maxExperiment=1, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_RedPCBv1 + data_RedPCBv2), data_RedPCBv1[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_RedPCBv1]*len(data_RedPCBv1)+[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['Version 1','Version 2'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper left', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_Version_Comparison')
# Out:
# Plotting SubthresholdCurve plot.
# Finished plotting SubthresholdCurve plot.
# Saving figures.
# Figures saved. (Seconds elapsed: 0.817838191986084)
# Saving figures.
# Figures saved. (Seconds elapsed: 0.5361800193786621)

# %%
color_RedPCB_ADC18bit = '#ed553b' #red
color_RedPCB_ADC19bit = '#7363af' #purple

# === Load Data ===
data_RedPCB_ADC18bit  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=1, maxExperiment=1, minRelativeIndex=0, maxRelativeIndex=0)
data_RedPCB_ADC19bit  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=3, maxExperiment=3, minRelativeIndex=1, maxRelativeIndex=1)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_RedPCB_ADC18bit + data_RedPCB_ADC19bit), data_RedPCB_ADC18bit[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_RedPCB_ADC18bit]*len(data_RedPCB_ADC18bit)+[color_RedPCB_ADC19bit]*len(data_RedPCB_ADC19bit), 'legendLabels':['18-bit ADC','19-bit ADC'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper left', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_ADCbitness_Comparison')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 1.142 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.588 s)

# %%
color_dart = '#7363af' #purple
color_B2900A = '#4FB99F' #green
color_B1500 = '#9F3285' #magenta

# === Load Data ===
data_B2900A = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/13-14',  'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_RedPCB = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/13-14',  'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)
data_B1500  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/13-14',  'GateSweep.json', minExperiment=9, maxExperiment=9, minRelativeIndex=0, maxRelativeIndex=0)

#for i in range(len(data_B2900A[0]['Results']['id_data'])):
    #data_B2900A[0]['Results']['id_data'][i] = -np.array(data_B2900A[0]['Results']['id_data'][i])
    #data_B1500[0]['Results']['id_data'][i] = -np.array(data_B1500[0]['Results']['id_data'][i])

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('TransferCurve', (data_B1500 + data_B2900A + data_RedPCB), data_B2900A[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[color_B1500]*len(data_B1500)+[color_B2900A]*len(data_B2900A)+[color_dart]*len(data_RedPCB), 'legendLabels':['B1500','B2900A','Dart'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper right', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_vs_B2900A_vs_B1500')

figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_B1500 + data_B2900A + data_RedPCB), data_B2900A[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'forward', 'colorsOverride':[color_B1500]*len(data_B1500)+[color_B2900A]*len(data_B2900A)+[color_dart]*len(data_RedPCB), 'legendLabels':['B1500','B2900A','Dart'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
axA1.legend(loc='upper right', handlelength=1)
dpu.saveExternalPlot(figA1, 'RedPCB_vs_B2900A_vs_B1500_subthreshold')
# Out:
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.706 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.536 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.721 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.421 s)

# %%
print(' === MOSFET Comparison Figure === ')

color_Signatone = '#9F3285' #magenta
color_Doherty   = '#4FB99F' #green
color_RedPCBv2  = '#7363af' #purple

# === Load Data ===
data_Signatone = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Signatone/IRF730/30-32', 'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_Doherty   = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/Doherty/IRF730/30-32',   'GateSweep.json', minExperiment=2, maxExperiment=2, minRelativeIndex=1, maxRelativeIndex=1)
data_RedPCBv2  = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/ECTools/RedPCBv2/IRF730/30-32',  'GateSweep.json', minExperiment=1, maxExperiment=1, minRelativeIndex=0, maxRelativeIndex=0)

# === Plot ===
figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_Signatone + data_RedPCBv2), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':[color_Signatone]*len(data_Signatone)+[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['$5k Source Meter','Versametrics Dart'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'System_Comparison')

figA1, (axA1,) = dpu.makeDevicePlot('TransferCurve', (data_Signatone + data_RedPCBv2), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':[color_Signatone]*len(data_Signatone)+[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['$5k Source Meter','Versametrics Dart'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'System_Comparison_2')

figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_RedPCBv2), data_Signatone[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'reverse', 'colorsOverride':[color_RedPCBv2]*len(data_RedPCBv2), 'legendLabels':['Versametrics Dart'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'System_Comparison_3')
# Out:
#  === MOSFET Comparison Figure ===
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 1.007 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.686 s)
# [PLOT]: Plotting TransferCurve plot.
# [PLOT]: Finished plotting TransferCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.630 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.365 s)
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.950 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.529 s)

# %%
data_B2900A_1 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/13-14',  'GateSweep.json', minExperiment=5, maxExperiment=5, minRelativeIndex=0, maxRelativeIndex=0)
data_B2900A_2 = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/13-14',  'GateSweep.json', minExperiment=8, maxExperiment=8, minRelativeIndex=0, maxRelativeIndex=0)

figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data_B2900A_1 + data_B2900A_2), data_B2900A_1[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'legendLabels':['B2900A','B2900A'], 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='lower left', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'Before_and_After')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.700 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.421 s)

# %%
color_RedPCBv2  = '#7363af' #purple

data = dlu.loadSpecificDeviceHistory('../../AutexysData/jay/Quartz/JP3/G/31-32',  'GateSweep.json', minExperiment=6, maxExperiment=6, minRelativeIndex=0, maxRelativeIndex=0)

figA1, (axA1,) = dpu.makeDevicePlot('SubthresholdCurve', (data), data[0]['Identifiers'], mode_parameters={'enableLegend':True, 'enableColorBar':False, 'sweepDirection':'both', 'legendLabels':['Dart'], 'colorsOverride':[color_RedPCBv2]*len(data), 'publication_mode':True, 'figureSizeOverride':(2,2.5)})
legend_title = axA1.get_legend().get_title().get_text()
axA1.legend(loc='upper right', title=legend_title, handlelength=1)
dpu.saveExternalPlot(figA1, 'Dart_1.0_Research_grade_device')
# Out:
# [PLOT]: Plotting SubthresholdCurve plot.
# [PLOT]: Finished plotting SubthresholdCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.746 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.577 s)

# %%
data_SMU4 = dlu.loadSpecificDeviceHistory('../../AutexysData/VPS/Project/Wafer/Chip/Device',  'DrainSweep.json', minExperiment=104, maxExperiment=104)
data_SMU3 = dlu.loadSpecificDeviceHistory('../../AutexysData/VPS/Project/Wafer/Chip/Device',  'DrainSweep.json', minExperiment=105, maxExperiment=105)
data_SMU2 = dlu.loadSpecificDeviceHistory('../../AutexysData/VPS/Project/Wafer/Chip/Device',  'DrainSweep.json', minExperiment=106, maxExperiment=106)
data_SMU1 = dlu.loadSpecificDeviceHistory('../../AutexysData/VPS/Project/Wafer/Chip/Device',  'DrainSweep.json', minExperiment=107, maxExperiment=107)


fig, (ax,) = dpu.makeDevicePlot('OutputCurve', (data_SMU4), data_SMU4[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[], 'yscale':1, 'publication_mode':True, 'figureSizeOverride':(1.6,2)})
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.set_yscale('log')
ax.set_ylim([5e-13, 3e-4])
dpu.saveExternalPlot(fig, 'VPS_SMU4')

fig, (ax,) = dpu.makeDevicePlot('OutputCurve', (data_SMU3), data_SMU3[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[], 'yscale':1, 'publication_mode':True, 'figureSizeOverride':(1.6,2)})
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.set_xticks([0,0.5,1,1.5,2,2.5])
ax.set_yscale('log')
ax.set_ylim([5e-13, 3e-4])
dpu.saveExternalPlot(fig, 'VPS_SMU3')

fig, (ax,) = dpu.makeDevicePlot('OutputCurve', (data_SMU2), data_SMU2[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[], 'yscale':1, 'publication_mode':True, 'figureSizeOverride':(1.6,2)})
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.set_xticks([0,0.5,1,1.5,2,2.5])
ax.set_yscale('log')
ax.set_ylim([5e-13, 3e-4])
dpu.saveExternalPlot(fig, 'VPS_SMU2')

fig, (ax,) = dpu.makeDevicePlot('OutputCurve', (data_SMU1), data_SMU1[0]['Identifiers'], mode_parameters={'enableLegend':False, 'enableColorBar':False, 'sweepDirection':'both', 'colorsOverride':[], 'yscale':1, 'publication_mode':True, 'figureSizeOverride':(1.6,2)})
ax.set_xlabel('Voltage (V)')
ax.set_ylabel('Current (A)')
ax.set_yscale('log')
ax.set_ylim([5e-13, 3e-4])
dpu.saveExternalPlot(fig, 'VPS_SMU1')
# Out:
# [PLOT]: Plotting OutputCurve plot.
# [PLOT]: Finished plotting OutputCurve plot.
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.443 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 0.823 s)
# [PLOT]: Plotting OutputCurve plot.
# [PLOT]: Finished plotting OutputCurve plot.
# [MPL]: Saving figures.
# /Users/jaydoherty/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# [MPL]: Figures saved. (Seconds elapsed: 0.439 s)
# [MPL]: Saving figures.
# [MPL]: Figures saved. (Seconds elapsed: 1.073 s)
# [PLOT]: Plotting OutputCurve plot.
# [PLOT]: Finished plotting OutputCurve plot.
# [MPL]: Saving figures.
# ...
